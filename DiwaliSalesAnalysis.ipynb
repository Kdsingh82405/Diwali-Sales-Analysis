# %%
# Import Required Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import .csv file
df = pd.read_csv("Diwali_Sales_Data.csv")
df
# Out:
#        User_ID     Cust_name  Product_ID Gender Age Group  Age Marital_Status  \
# 0      1000545  Aditya Yadav        5805      M     18-25   22      Unmarried
# 1      1003759  Suman Mishra        8611      F     18-25   20        Married
# 2      1004167  Anita Mishra        6349      F     46-55   46        Married
# 3      1004402   Amit Chopra        1267      M     36-45   41        Married
# 4      1001439    Kavya Iyer        4667      F     26-35   30        Married
# ...        ...           ...         ...    ...       ...  ...            ...
# 11246  1006176  Aditya Mehta        9161      M     36-45   42      Unmarried
# 11247  1003398   Rahul Joshi        3600      M     26-35   31        Married
# 11248  1005049   Anita Singh        9327      F     36-45   43        Married
# 11249  1006495   Pooja Reddy        5801      F     36-45   43        Married
# 11250  1002811   Suman Patel        9821      F     26-35   35        Married
#
#                 State     Zone  Occupation Product_Category  Orders  Amount  \
# 0         Maharashtra     West        Govt         Clothing       2   21959
# 1      Andhra Pradesh     East  Healthcare             Home       7   32539
# 2       Uttar Pradesh    North     Student             Home       7   38458
# 3           Karnataka    North          IT         Clothing       5   33469
# 4             Gujarat    South          IT           Sports       5   12015
# ...               ...      ...         ...              ...     ...     ...
# 11246     Maharashtra    North  Healthcare         Clothing       9   23334
# 11247         Haryana  Central  Healthcare             Home       4   11412
# 11248  Madhya Pradesh     East        Govt         Clothing       3   38213
# 11249       Karnataka    North  Healthcare             Home       6   29873
# 11250     Maharashtra     East    Business             Home       6    8657
#
#           Status  unnamed1
# 0        Pending       362
# 1        Pending       732
# 2        Pending       212
# 3      Cancelled       784
# 4      Delivered       911
# ...          ...       ...
# 11246  Cancelled       649
# 11247    Pending       815
# 11248  Cancelled       978
# 11249    Pending       181
# 11250   Returned       663
#
# [11251 rows x 15 columns]

# %%
# Too See Top 15 Data
df.head(15)
# Out:
#     User_ID     Cust_name  Product_ID Gender Age Group  Age Marital_Status  \
# 0   1000545  Aditya Yadav        5805      M     18-25   22      Unmarried
# 1   1003759  Suman Mishra        8611      F     18-25   20        Married
# 2   1004167  Anita Mishra        6349      F     46-55   46        Married
# 3   1004402   Amit Chopra        1267      M     36-45   41        Married
# 4   1001439    Kavya Iyer        4667      F     26-35   30        Married
# 5   1000831    Karan Nair        3710      M     18-25   24        Married
# 6   1006417   Riya Mishra        7071      F     36-45   45      Unmarried
# 7   1002895   Rahul Reddy        7689      M     46-55   46        Married
# 8   1002675   Amit Kapoor        4932      M     18-25   25      Unmarried
# 9   1001467  Mohit Mishra        5318      M     36-45   41      Unmarried
# 10  1006767   Pooja Patel        5486      F     46-55   47        Married
# 11  1002772    Rahul Iyer        1100      M     36-45   37        Married
# 12  1004996   Vikas Mehta        5008      M     46-55   53        Married
# 13  1005313  Vikas Mishra        3277      M     26-35   35        Married
# 14  1006370    Raj Kapoor        8755      M     26-35   34      Unmarried
#
#                State     Zone  Occupation Product_Category  Orders  Amount  \
# 0        Maharashtra     West        Govt         Clothing       2   21959
# 1     Andhra Pradesh     East  Healthcare             Home       7   32539
# 2      Uttar Pradesh    North     Student             Home       7   38458
# 3          Karnataka    North          IT         Clothing       5   33469
# 4            Gujarat    South          IT           Sports       5   12015
# 5   Himachal Pradesh    North  Healthcare             Home       9   37159
# 6      Uttar Pradesh    North    Business         Clothing       7   46624
# 7        Maharashtra     West          IT           Sports       7   35088
# 8      Uttar Pradesh    North          IT          Grocery       3   19398
# 9     Andhra Pradesh  Central          IT             Home       4   26159
# 10             Delhi     West    Business          Grocery       3   17341
# 11    Andhra Pradesh     West    Business          Grocery       9   31039
# 12    Andhra Pradesh  Central  Healthcare             Home       1   24522
# 13    Andhra Pradesh    North        Govt           Sports       6   40658
# 14    Madhya Pradesh     West  Healthcare         Clothing       9   36395
#
#        Status  unnamed1
# 0     Pending       362
# 1     Pending       732
# 2     Pending       212
# 3   Cancelled       784
# 4   Delivered       911
# 5   Cancelled       497
# 6    Returned       470
# 7    Returned       714
# 8   Delivered       916
# 9     Pending       286
# 10   Returned       349
# 11    Pending       538
# 12  Delivered       411
# 13  Cancelled       738
# 14   Returned       478

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  int64
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  object
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11251 non-null  int64
#  13  Status            11251 non-null  object
#  14  unnamed1          11251 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 1.3+ MB

# %%
# Drop Column Here axis=1 Means Remove Entire Rows Of The Column
df.drop(['unnamed1'],axis=1,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  int64
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  object
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11251 non-null  int64
#  13  Status            11251 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.2+ MB

# %%
 pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# Status              0
# dtype: int64

# %%
df.shape
# Out:
# (11251, 14)

# %%
# Column Rename Or Change The Name Of Columns
df.rename(columns = {'Orders':'Total_Orders'})
# Out:
#        User_ID     Cust_name  Product_ID Gender Age Group  Age Marital_Status  \
# 0      1000545  Aditya Yadav        5805      M     18-25   22      Unmarried
# 1      1003759  Suman Mishra        8611      F     18-25   20        Married
# 2      1004167  Anita Mishra        6349      F     46-55   46        Married
# 3      1004402   Amit Chopra        1267      M     36-45   41        Married
# 4      1001439    Kavya Iyer        4667      F     26-35   30        Married
# ...        ...           ...         ...    ...       ...  ...            ...
# 11246  1006176  Aditya Mehta        9161      M     36-45   42      Unmarried
# 11247  1003398   Rahul Joshi        3600      M     26-35   31        Married
# 11248  1005049   Anita Singh        9327      F     36-45   43        Married
# 11249  1006495   Pooja Reddy        5801      F     36-45   43        Married
# 11250  1002811   Suman Patel        9821      F     26-35   35        Married
#
#                 State     Zone  Occupation Product_Category  Total_Orders  \
# 0         Maharashtra     West        Govt         Clothing             2
# 1      Andhra Pradesh     East  Healthcare             Home             7
# 2       Uttar Pradesh    North     Student             Home             7
# 3           Karnataka    North          IT         Clothing             5
# 4             Gujarat    South          IT           Sports             5
# ...               ...      ...         ...              ...           ...
# 11246     Maharashtra    North  Healthcare         Clothing             9
# 11247         Haryana  Central  Healthcare             Home             4
# 11248  Madhya Pradesh     East        Govt         Clothing             3
# 11249       Karnataka    North  Healthcare             Home             6
# 11250     Maharashtra     East    Business             Home             6
#
#        Amount     Status
# 0       21959    Pending
# 1       32539    Pending
# 2       38458    Pending
# 3       33469  Cancelled
# 4       12015  Delivered
# ...       ...        ...
# 11246   23334  Cancelled
# 11247   11412    Pending
# 11248   38213  Cancelled
# 11249   29873    Pending
# 11250    8657   Returned
#
# [11251 rows x 14 columns]

# %%
df.describe()
# Out:
#             User_ID    Product_ID           Age        Orders        Amount
# count  1.125100e+04  11251.000000  11251.000000  11251.000000  11251.000000
# mean   1.003530e+06   5502.008799     39.999911      4.995200  25108.864990
# std    2.031925e+03   2581.794650     11.164933      2.590302  14260.396693
# min    1.000001e+06   1001.000000     20.000000      1.000000    508.000000
# 25%    1.001760e+06   3261.500000     30.000000      3.000000  12822.000000
# 50%    1.003517e+06   5513.000000     40.000000      5.000000  24860.000000
# 75%    1.005292e+06   7719.500000     49.000000      7.000000  37487.000000
# max    1.007040e+06   9997.000000     60.000000      9.000000  49996.000000

# %%
# Use describe() for specific columns
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11251.000000
# mean      39.999911      4.995200  25108.864990
# std       11.164933      2.590302  14260.396693
# min       20.000000      1.000000    508.000000
# 25%       30.000000      3.000000  12822.000000
# 50%       40.000000      5.000000  24860.000000
# 75%       49.000000      7.000000  37487.000000
# max       60.000000      9.000000  49996.000000

# %%
# To See All Columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
ax = sns.countplot(x='Gender', data=df,hue='Gender',palette='bright')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gen = df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sales_gen
# Out:
#   Gender     Amount
# 1      M  183234947
# 0      F   99264893

# %%
sns.barplot(x='Gender',y='Amount',data=sales_gen,hue='Gender',palette='bright')
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [raw]
# From above graphs we can see that most of the buyers are Male and even the purchasing power of Male are greater than female

# %% [markdown]
# # AGE

# %%
ax=sns.countplot(data=df, x='Age Group', hue='Gender',palette='bright')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_age=df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Age Group',y='Amount' ,data=sales_age,hue='Age Group',palette='bright',legend=False)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [raw]
# From above graphs we can see that most of the buyers are of age group between 46-55 yrs Male

# %%
# Total Number of Orders from top 10 States
sales_state=df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data=sales_state, x='State',y='Orders',hue='State',palette='bright')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# Total Amount/Sales from top 10 States
sales_state=df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(16,5)})
sns.barplot(data=sales_state, x='State',y='Amount',hue='State',palette='bright')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [raw]
# From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# # Marital Status

# %%
ax = sns.countplot(data=df,x='Marital_Status',hue='Marital_Status',palette='bright')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount/Sales from top 10 States
sales_state=df.groupby(['Marital_Status','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data=sales_state, x='Marital_Status',y='Amount',hue='Gender',palette='bright')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [raw]
# From above graphs we can see that most of the buyers are married (Male) and they have high purchasing power

# %% [markdown]
# # Occupation

# %%
sns.set(rc={'figure.figsize':(7,4)})
ax = sns.countplot(data = df, x = 'Occupation',hue='Occupation',palette='bright')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(7,4)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount',hue='Occupation',palette='bright')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [raw]
# From above graphs we can see that most of the buyers are working in Education, IT and Business Sector

# %% [markdown]
# # Product Category

# %%
sns.set(rc={'figure.figsize':(7,4)})
ax = sns.countplot(data = df, x = 'Product_Category',hue='Product_Category',palette='bright')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(7,4)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount',hue='Product_Category',palette='bright')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [raw]
# From above graphs we can see that most of the sold products are from Electronics, Sports and Grocery category

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders',hue='Product_ID',palette='bright')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# # Conclusion:

# %% [raw]
# Married Men age group 46-55 yrs from Uttar Pradesh, Maharashtra and Karnataka working in Education,IT and Business are more likely to buy products from Electronics, Sports and Grocery category.
